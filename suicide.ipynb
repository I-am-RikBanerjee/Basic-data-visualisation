# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns
# %matplotlib inline

# %%
suicide=pd.read_csv('suicidedataset.csv')
suicide.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
suicide.info()
suicide.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# country-year          27820 non-null object
# HDI for year          8364 non-null float64
#  gdp_for_year ($)     27820 non-null object
# gdp_per_capita ($)    27820 non-null int64
# generation            27820 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# ...

# %%
suicide.drop(['suicides/100k pop','HDI for year','gdp_per_capita ($)'],axis=1,inplace=True)
suicide.head()
# Out:
#    country  year     sex          age  suicides_no  population country-year  \
# 0  Albania  1987    male  15-24 years           21      312900  Albania1987
# 1  Albania  1987    male  35-54 years           16      308000  Albania1987
# 2  Albania  1987  female  15-24 years           14      289700  Albania1987
# 3  Albania  1987    male    75+ years            1       21800  Albania1987
# 4  Albania  1987    male  25-34 years            9      274300  Albania1987
#
#    gdp_for_year ($)        generation
# 0      2,156,624,900     Generation X
# 1      2,156,624,900           Silent
# 2      2,156,624,900     Generation X
# 3      2,156,624,900  G.I. Generation
# 4      2,156,624,900          Boomers

# %%
#1done suicide no for australia from 2000 to 2015
mask1=suicide['country-year']=='Australia2000'
mask2=suicide['country-year']=='Australia2001'
mask3=suicide['country-year']=='Australia2002'
mask4=suicide['country-year']=='Australia2003'
mask5=suicide['country-year']=='Australia2004'
mask6=suicide['country-year']=='Australia2005'
mask7=suicide['country-year']=='Australia2006'
mask8=suicide['country-year']=='Australia2007'
mask9=suicide['country-year']=='Australia2008'
mask10=suicide['country-year']=='Australia2009'
mask11=suicide['country-year']=='Australia2010'
mask12=suicide['country-year']=='Australia2011'
mask13=suicide['country-year']=='Australia2012'
mask14=suicide['country-year']=='Australia2013'
mask15=suicide['country-year']=='Australia2014'
mask16=suicide['country-year']=='Australia2015'
mask18=suicide['country-year']=='Australia1985'
mask19=suicide['country-year']=='Australia1986'
mask20=suicide['country-year']=='Australia1987'
mask21=suicide['country-year']=='Australia1988'
mask22=suicide['country-year']=='Australia1989'
mask23=suicide['country-year']=='Australia1990'
mask24=suicide['country-year']=='Australia1991'
mask25=suicide['country-year']=='Australia1992'
mask26=suicide['country-year']=='Australia1993'
mask27=suicide['country-year']=='Australia1994'
mask28=suicide['country-year']=='Australia1995'
mask29=suicide['country-year']=='Australia1996'
mask30=suicide['country-year']=='Australia1997'
mask31=suicide['country-year']=='Australia1998'
mask32=suicide['country-year']=='Australia1999'
#mask17=suicide['sex']=='male'
suicide_australia=suicide[mask1|mask2|mask3|mask4|mask5|mask6|mask7|mask8|mask9|mask10|mask11|mask12|mask13|mask14|mask15|mask16
                         |mask18|mask19|mask20|mask21|mask22|mask23|mask24|mask25|mask26|mask27|mask28|mask29|mask30|mask31|mask32]
suicide_australia.info()
suicide_australia.groupby('age')['suicides_no'].agg('sum').sort_values(ascending=False).plot(kind='bar')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360 entries, 1426 to 1785
# Data columns (total 9 columns):
# country               360 non-null object
# year                  360 non-null int64
# sex                   360 non-null object
# age                   360 non-null object
# suicides_no           360 non-null int64
# population            360 non-null int64
# country-year          360 non-null object
#  gdp_for_year ($)     360 non-null object
# generation            360 non-null object
# dtypes: int64(3), object(6)
# memory usage: 28.1+ KB

# %%
#2done
suicide_australia.groupby('country-year')['suicides_no'].agg('sum').plot(kind='bar')

# %%
#3done all over the world suicide according to the age grp
suicide.groupby('age')['suicides_no'].agg('sum').plot(kind='bar')

# %%
#done take age gap and dive it between male and female

### Set figure size
plt.figure(figsize=(16,7))
###Let's plot the barplot
bar_age = sns.barplot(x = 'age', y = 'suicides_no', hue = 'sex',data = suicide)

# %%
#done take sex and dive it between age gaps

### Set figure size
plt.figure(figsize=(16,7))
###Let's plot the barplot
bar_age = sns.barplot(x = 'sex', y = 'suicides_no', hue = 'age',data = suicide)

# %%
suicide.tail()
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#          country-year  gdp_for_year ($)     generation
# 27815  Uzbekistan2014     63,067,077,179  Generation X
# 27816  Uzbekistan2014     63,067,077,179        Silent
# 27817  Uzbekistan2014     63,067,077,179  Generation Z
# 27818  Uzbekistan2014     63,067,077,179  Generation Z
# 27819  Uzbekistan2014     63,067,077,179       Boomers

# %%
#5 world population growth(according to our data set we do not have data for some major countries like india)
#error why dn't know pr

# %%
suicide.groupby('sex')['population'].agg('sum').sort_values(ascending=False).plot(kind='bar',title='population male vs female')

# %%
#done 
suicide.groupby('sex')['suicides_no'].agg('sum').sort_values(ascending=False).plot(kind='bar',title='sucide comitted male vs female')

# %%
#done since 1985 suicide no
suicide.groupby('country')['suicides_no'].agg('sum').sort_values(ascending=False).head(10)
# Out:
# country
# Russian Federation    1209742
# United States         1034013
# Japan                  806902
# France                 329127
# Ukraine                319950
# Germany                291262
# Republic of Korea      261730
# Brazil                 226613
# Poland                 139098
# United Kingdom         136805
# Name: suicides_no, dtype: int64

# %%
#done suicide only in 2010
mask34=suicide['year']==2010
suicide_2010=suicide[mask34]
suicide_2010.groupby('country')['suicides_no'].agg('sum').sort_values(ascending=False).head(10).plot(kind='bar',title='In 2010 suicide no by top 10 country')

# %%
suicide_2010.groupby('country')['population'].agg('sum').sort_values(ascending=False).head(10).plot(kind='pie',title='in 2000 population in top 10 country')

# %%
suicide.head()
# Out:
#    country  year     sex          age  suicides_no  population country-year  \
# 0  Albania  1987    male  15-24 years           21      312900  Albania1987
# 1  Albania  1987    male  35-54 years           16      308000  Albania1987
# 2  Albania  1987  female  15-24 years           14      289700  Albania1987
# 3  Albania  1987    male    75+ years            1       21800  Albania1987
# 4  Albania  1987    male  25-34 years            9      274300  Albania1987
#
#    gdp_for_year ($)        generation
# 0      2,156,624,900     Generation X
# 1      2,156,624,900           Silent
# 2      2,156,624,900     Generation X
# 3      2,156,624,900  G.I. Generation
# 4      2,156,624,900          Boomers

# %%
#done
suicide['generation'].value_counts()
# Out:
# Generation X       6408
# Silent             6364
# Millenials         5844
# Boomers            4990
# G.I. Generation    2744
# Generation Z       1470
# Name: generation, dtype: int64

# %%
###Let's check for country
alpha =0.8
plt.figure(figsize=(10,20))
sns.countplot(y='country', data=suicide, alpha=alpha)
plt.title('Data by country')
plt.show()

# %%
plt.figure(figsize=(16,7))
cor = sns.heatmap(suicide.corr(), annot =True)

# %%
#done now plot which generation has most suicide number
plt.figure(figsize=(16,7))
sns.barplot(x = 'sex', y = 'suicides_no', hue = 'generation',data = suicide)

# %%
#done suicide yearwise worlwide
suicide.groupby('year')['suicides_no'].agg('sum').plot(kind='bar')

# %%
#above same by line plot also age gap come into action
mask100=suicide['age']=='15-24 years'
mask101=suicide['age']=='35-54 years'
mask102=suicide['age']=='25-34 years'
mask103=suicide['age']=='5-14 years'
mask104=suicide['age']=='75+ years'
mask105=suicide['age']=='55-74 years'
suicide_age5=suicide[mask103]
suicide_age15=suicide[mask100]
suicide_age25=suicide[mask102]
suicide_age35=suicide[mask101]
suicide_age55=suicide[mask105]
suicide_age75=suicide[mask104]

plt.figure(figsize=(16,7))

#age_5_lp = sns.barplot(x='year', y='suicides_no', data=suicide_age5)
#age_15_lp = sns.barplot(x='year', y='suicides_no', data=suicide_age15)
#age_25_lp = sns.lineplot(x='year', y='suicides_no', data=suicide_age25)
age_35_lp = sns.barplot(x='year', y='suicides_no', data=suicide_age35)
#age_55_lp = sns.lineplot(x='year', y='suicides_no', data=suicide_age55)
#age_75_lp = sns.lineplot(x='year', y='suicides_no', data=suicide_age75)



plt.legend(['5-14 years', '15-24 years', '25-34 years', '35-54 years', '55-74 years', '75+ years'])
